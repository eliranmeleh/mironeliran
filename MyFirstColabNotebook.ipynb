# %% [markdown]
# <a href="https://colab.research.google.com/github/eliranmeleh/mironeliran/blob/main/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Sat Nov  1 15:01:44 2025

# %%
time.sleep(5)
print(time.ctime())
# Out:
# Sat Nov  1 15:01:49 2025
